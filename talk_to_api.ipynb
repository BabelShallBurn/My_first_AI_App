# %%
import requests

URL_QUERY = "http://localhost:5004/run_query"
URL_PERPLEXITY = "http://localhost:5004/ask_perplexity"
URL_CHATGPT = "http://localhost:5004/ask_chatgpt"

# %%
data = {'id': '1234', 'query': 'What is the capital of France?'}
response = requests.post(URL_QUERY, json=data)
print(response.json())
# Out:
# {'query': 'What is the capital of France?'}

# %%
data = {'query': 'What is the largest planet in our solar system?'}
response = requests.post(URL_QUERY, json=data)
print(response.json())
# Out:
# [{'input': {'query': 'What is the largest planet in our solar system?'}, 'loc': ['id'], 'msg': 'Field required', 'type': 'missing', 'url': 'https://errors.pydantic.dev/2.12/v/missing'}]

# %%
data = {'id': '5678', 'query': 'What\'s Machine Learning?'}
response = requests.post(URL_PERPLEXITY, json=data)
print(response.json())
# Out:
# **Machine Learning (ML)** is a branch of artificial intelligence that enables computers to learn from data and improve their performance on tasks without being explicitly programmed for each specific task. Instead of following fixed instructions, ML systems use algorithms to identify patterns in data, make predictions, or take actions based on experience from past data[1][2][3][4][5].
#
# Key points about machine learning include:
#
# - **Data-driven learning:** ML models rely on large datasets to uncover patterns and relationships that help make predictions or decisions[1][2].
#
# - **Algorithmic foundation:** Different algorithms analyze data, extract insights, and optimize decision-making, continuously improving as more data is processed[1][3].
#
# ...

# %%
data = {'id': '5678', 'query': 'What\'s Machine Learning?'}
response = requests.post(URL_CHATGPT, json=data)
print(response.json())
# Out:
# Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform tasks without explicit programming. Instead of following predetermined rules, machine learning systems learn from data. Through this learning process, these systems can identify patterns, make decisions, and improve their performance over time based on experience.
#
# Here are some key concepts related to machine learning:
#
# 1. **Types of Learning**:
#    - **Supervised Learning**: The algorithm is trained on a labeled dataset, meaning that the outcomes are known. It learns to predict the output from the input data.
#    - **Unsupervised Learning**: The algorithm works with unlabeled data and tries to find hidden patterns or intrinsic structures in the input data.
# ...
